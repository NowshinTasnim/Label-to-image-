# %%
#imports
from tensorflow.keras.models import load_model
import tensorflow as tf
import tensorflowjs as tfjs
import tensorflow.contrib.eager as tfe
tf.enable_eager_execution()

# %%
# Drive_mount
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#tensorflowjs install
# !pip install tensorflowjs

# %%
#tensorflowjs install
# !pip install tensorflowjs==1.2.6

# %%
#load the saved model
model = load_model("/content/gdrive/My Drive/Projects/text_to_image/model.h5")

# %%
#convert keras model into json 
tfjs_target_dir = "/content/gdrive/My Drive/Projects/text_to_image/model/"
tfjs.converters.save_keras_model(model, tfjs_target_dir)
